# %% [markdown]
# # First Deliverable for FCD

# %% [markdown]
# ## Objectives of the project

# %% [markdown]
# 1. Data mining news articles related to André Ventura / CHEGA (potentially only headlines at first)
# 	- Timeframe 2019-2024
# 2. Word cloud analysis since the party foundation, assess the topics of interest throughout the years
# 3. Correlation with INE (National Institute of Statistics) data with the various topics (identify real trends, or made up trends by fake news/social media)
# 4. Change of the party’s position regarding the identified topics
# 5. Word clouds every 5 years of the portuguese politics landscape (2000-2005-2010-2015-2020)

# %% [markdown]
# ## Script to make requests from ARQUIVO's CDX API

# %% [markdown]
# ---
# In the first part of the script we defined the newspapers to search for (yes, CDX API makes you search by a *single* url at a time), and the function that will look them up.
#
# ---
# ### Challenges with the CDX API
#
# The CDX API can access any stored link in **arquivo API**, but it can only be filtered with some metadata and text within the URL
# - We made use of timestamps to limit our search to the period of interest. However,  it doesn't mean that all the pages collected are from that period, as there are several snapshots from pages way before 2019
# - We looked up link by link (out of 12 newspapers selected, across the political spectrum), and looked for the tags '-chega-' and 'ventura'
#     - Filtering for '-chega-' helped reduce the number of outliers by avoiding words where 'chega' can be found (e.g., chegado, aconchega)
#     - In the case of 'ventura' the outliers weren't that many, and we had no big issues

# %%
import requests
import json
import time


# Define the API endpoint
cdx_url = "https://arquivo.pt/wayback/cdx"

# Newspapers to search
newsp = ['cmjornal.pt/*', 
         'dn.pt/*',
         'expresso.pt/*',
         'folhanacional.pt/*',
         'jn.pt/*',
         'ionline.sapo.pt/*',   
         'sol.sapo.pt/*',
         'observador.pt/*',
         'publico.pt/*',
         'sabado.pt/*',
         'sapo.pt/*',
         'visao.pt/*',
         ]

# Tags to search within newspaper's links
tags = ['-chega-', 'ventura'] # needed to add dashes before and after "chega" in order to avoid other words containing it 

# Process the response into a list
data = []

# Define the maximum number of retries
max_retries = 2
delay_between_requests = 5 # seconds

# Function to handle requests with retries and delays
def fetch_data_w_retries(url, params, retries=max_retries):
    """
    Makes a GET request to the given URL with the given parameters, and 
    retries the request up to 'retries' times if it fails. If the request 
    fails after all retries, returns None.
    
    :param url: str, the URL to make the request to
    :param params: dict, the parameters to send with the request
    :param retries: int, the number of times to retry the request if it fails
    :return: requests.Response, or None if the request fails after all retries
    """
    for attempt in range(retries):
        try:
            response = requests.get(url, params=params, timeout=150)
            response.raise_for_status() # Raise an error for 4xx or 5xx responses
            return response
        except requests.exceptions.RequestException as e:
            print(f"Request failed: {e}. Attempt {attempt + 1} of {retries}")
            if attempt < retries - 1:
                print(f"Retrieved {len(data)} records.")
                time.sleep(delay_between_requests) # Wait before retrying
            else:
                print("Max retries reached. Skipping.")
                return None

# %% [markdown]
# ---
# Both in the function and the rest of the script we had to manage several error inducing scenarios such as:
# - Blank error status
# - Process the data as NDJSON instead of JSON
# - Exceeding read time out

# %%
# Check if the response is in NDJSON format
for i in newsp:
    for tag in tags:
        params = {
        'url': i,
        'fields': 'url,timestamp,status',
        'from': '2022',
        'to': '2024',
        'filter': 'original:'+tag,
        'output': 'json',
        'limit': '5000'
        }
        
        response = fetch_data_w_retries(cdx_url, params)

        if response:
            if response.status_code == 200:
                if response.headers.get('Content-Type') == 'text/x-ndjson':
                    # Process each line as a separate JSON object
                    for line in response.text.splitlines():
                        try:
                            record = json.loads(line)

                            status = record.get('status')

                            if status == '200':
                                data.append(record)
                            else:
                                if status is None:
                                    print(f"Record missing 'status' field: {record}")
                                    print(f"Retrieved {len(data)} records.")

                                else:
                                    print(f"Record with status '{status}': {record}")
                                    print(f"Retrieved {len(data)} records.")

                        except json.JSONDecodeError as e:
                            print(f"Error parsing line: {line}")
                            print(f"JSONDecodeError: {e}")
                        except TypeError as e:
                            print(f"Unexpected data format: {line}")
                            print(f"TypeError: {e}")
                else:
                    print("Response is not in NDJSON format.")
            else:
                print(f"Failed to retrieve data: {response.status_code}")
        else:
            print("Failed to retrieve data.")

# Print the number of records retrieved
print(f"Retrieved {len(data)} records.")

# Insert the new data into cdx_results.json
with open("cdx_results.json", "w") as json_file:
    json.dump(data, json_file, indent=4)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [6], in <cell line: 2>()
#       3 for tag in tags:
#       4     params = {
#       5     'url': i,
#       6     'fields': 'url,timestamp,status',
#    (...)
#      11     'limit': '5000'
#      12     }
# ---> 14     response = fetch_data_w_retries(cdx_url, params)
#      16     if response:
#      17         if response.status_code == 200:
#
# Input In [5], in fetch_data_w_retries(url, params, retries)
#      46 for attempt in range(retries):
#      47     try:
# ---> 48         response = requests.get(url, params=params, timeout=150)
#      49         response.raise_for_status() # Raise an error for 4xx or 5xx responses
#      50         return response
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File ~/opt/anaconda3/lib/python3.9/http/client.py:1377, in HTTPConnection.getresponse(self)
#    1375 try:
#    1376     try:
# -> 1377         response.begin()
#    1378     except ConnectionError:
#    1379         self.close()
#
# File ~/opt/anaconda3/lib/python3.9/http/client.py:320, in HTTPResponse.begin(self)
#     318 # read until we get a non-100 response
#     319 while True:
# --> 320     version, status, reason = self._read_status()
#     321     if status != CONTINUE:
#     322         break
#
# File ~/opt/anaconda3/lib/python3.9/http/client.py:281, in HTTPResponse._read_status(self)
#     280 def _read_status(self):
# --> 281     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282     if len(line) > _MAXLINE:
#     283         raise LineTooLong("status line")
#
# File ~/opt/anaconda3/lib/python3.9/socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# File ~/opt/anaconda3/lib/python3.9/ssl.py:1242, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1238     if flags != 0:
#    1239         raise ValueError(
#    1240           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1241           self.__class__)
# -> 1242     return self.read(nbytes, buffer)
#    1243 else:
#    1244     return super().recv_into(buffer, nbytes, flags)
#
# File ~/opt/anaconda3/lib/python3.9/ssl.py:1100, in SSLSocket.read(self, len, buffer)
#    1098 try:
#    1099     if buffer is not None:
# -> 1100         return self._sslobj.read(len, buffer)
#    1101     else:
#    1102         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# #### Scrapping words out of received URLs
#
# - Open every website and webscrape the title-element in the HTML-Script
#
# - Safe the original URL as Key and the extracted words as value in a dictionary, if the title contains 'Chega' or 'CHEGA'
# - Write it into a new .json file

# %%
import json
import requests
from bs4 import BeautifulSoup
import time

# Path to the JSON file
file_name = 'cdx_results_2019.json'

# Open and load the JSON file
with open(file_name, 'r') as file:
    data = json.load(file)

titles = {}

# Loop through URLs; search for the title element in HTML-Script
counter = 0

for v in data:
    url = v['url']
    print(f'iteration {counter}')
    print(f'link: {url}')
    counter += 1
    
    try:
        # Requesting the website and setting a timeout of 10 seconds
        response = requests.get(url, timeout=10, stream=True) # stream=True for downloading data in chunks not everything at once 
        
        # Delay between requests to avoid overloading the server
        # time.sleep(1)  # 1-second delay; should may be in code if server gets too much requests, for now works fine without delay

        # Initialize an empty content variable and stream content chunks
        html_content = b""
        
        # Stream the content until we find the closing </title> tag
        for chunk in response.iter_content(chunk_size=512):
            html_content += chunk
            if b"</title>" in html_content:
                break  # Stop streaming once the <title> tag is found

        # Parse only the partial content with BeautifulSoup
        soup = BeautifulSoup(html_content, "html.parser") # optional lxml parser

        # Extract the <title> element
        title_tag = soup.find("title")

        # If no <title> tag is found, skip this page, makes program faster
        if not title_tag:
            continue

        # Extract the text from the <title> tag
        title_text = title_tag.get_text()

        # Check for "Chega" or "CHEGA" (case-sensitive check)
        if "Chega" in title_text or "CHEGA" in title_text:
            print(f'title text "{title_text}" is valid"')
            titles[url] = title_text  # Store the URL and title in the dictionary

    except requests.exceptions.Timeout:
        print(f"Timeout occurred for URL: {url}")
        continue  # Skip to the next URL if a timeout occurs

    except requests.exceptions.RequestException as e:
        print(f"Request failed for URL: {url} with error: {e}")
        continue  # Skip to the next URL if another error occurs

# Writing the dictionary to a JSON file
with open('titles.json', 'w', encoding='utf-8') as json_file:
    json.dump(titles, json_file, indent=4, ensure_ascii=False)
# Out:
# iteration 0
# link: https://www.cmjornal.pt/boa-vida/amp/capital-do-natal-chega-a-oeiras
# iteration 1
# link: https://www.cmjornal.pt/boa-vida/amp/capital-do-natal-chega-a-oeiras
# iteration 2
# link: https://www.cmjornal.pt/boa-vida/detalhe/capital-do-natal-chega-a-oei
# link: https://www.cmjornal.pt/boa-vida/tendencias/detalhe/festival-gastronomia-de-bordo-chega-ao-mercado-de-peniche?ref=HP_CMaoMinuto&act=0&est=Aberto
# iteration 62
# link: https://www.cmjornal.pt/boa-vida/tendencias/detalhe/festival-gastronomia-de-bordo-chega-ao-mercado-de-peniche?ref=Modalidades_CmaoMinuto&act=0&est=Aberto
# iteration 63
# link: https://www.cmjornal.pt/boa-vida/tendencias/detalhe/festival-gastronomia-de-bordo-chega-ao-mercado-de-peniche?ref=Mundial2018_CmaoMinuto&act=0&est=Aberto
# iteration 64
# link: https://www.cmjornal.pt/boa-vida/tendencias/detalhe/festival-gastronomia-de-bordo-chega-ao-mercado-de-peniche?ref=Portugal_CmaoMinuto&act=0&est=Aberto
# iteration 65
# link: https://www.cmjornal.pt/boa-vida/tendencias/detalhe/festival-gastronomia-de-bordo-chega-ao-mercado-de-peniche?ref=Programas_CMaoMinuto_2&act=0&est=Aberto
# iteration 66
# link: https://www.cmjornal.pt/boa-vida/tendencias/detalhe/festival-gastronomia-de-bordo-chega-ao-mercado-de-peniche?ref=Sociedade_CmaoMinuto&act=0&est=Aberto
# iteration 67
# link: https://www.cmjornal.pt/boa-vida/tendencias/detalhe/festival-gastronomia-de-bordo-chega-ao-mercado-de-peniche?utm_medium=Social&utm_source=EnviarAmigo&utm_campaign=BotoesSite&utm_content=EnviarAmigo&act=0&est=Aberto
# iteration 68
# link: https://www.cmjornal.pt/boa-vida/tendencias/detalhe/festival-gastronomia-de-bordo-chega-ao-mercado-de-peniche?ref=Cidades_CmaoMinuto
# iteration 69
# link: https://www.cmjornal.pt/boa-vida/tendencias/detalhe/festival-gastronomia-de-bordo-chega-ao-mercado-de-peniche?ref=Clima_CmaoMinuto
# iteration 70
# link: https://www.cmjornal.pt/boa-vida/tendencias/detalhe/festival-gastronomia-de-bordo-chega-ao-mercado-de-peniche?ref=CmaoMinuto_DestaquesPrincipais
# iteration 71
# link: https://www.cmjornal.pt/boa-vida/tendencias/detalhe/festival-gastronomia-de-bordo-chega-ao-mercado-de-peniche?ref=Colunistas_DestaquesPrincipais
# iteration 72
# link: https://www.cmjornal.pt/boa-vida/tendencias/detalhe/festival-gastronomia-de-bordo-chega-ao-mercado-de-peniche?ref=Colunistas_DestaquesPrincipais
# iteration 73
# link: https://www.cmjornal.pt/boa-vida/tendencias/detalhe/festival-gastronomia-de-bordo-chega-ao-mercado-de-peniche?ref=Desporto_CmaoMinuto
# iteration 74
# link: https://www.cmjornal.pt/boa-vida/tendencias/detalhe/festival-gastronomia-de-bordo-chega-ao-mercado-de-peniche?ref=DET_CMaoMinuto_2
# iteration 75
# link: https://www.cmjornal.pt/boa-vida/tendencias/detalhe/festival-gastronomia-de-bordo-chega-ao-mercado-de-peniche?ref=DET_MaisVistasArea
# iteration 76
# link: https://www.cmjornal.pt/boa-vida/tendencias/detalhe/festival-gastronomia-de-bordo-chega-ao-mercado-de-peniche?ref=DET_MaisVistasArea
# iteration 77
# link: https://www.cmjornal.pt/boa-vida/tendencias/detalhe/festival-gastronomia-de-bordo-chega-ao-mercado-de-peniche?ref=Economia_CmaoMinuto
# iteration 78
# link: https://www.cmjornal.pt/boa-vida/tendencias/detalhe/festival-gastronomia-de-bordo-chega-ao-mercado-de-peniche?ref=Exclusivos_CmaoMinuto
# iteration 79
# link: https://www.cmjornal.pt/boa-vida/tendencias/detalhe/festival-gastronomia-de-bordo-chega-ao-mercado-de-peniche?ref=FalarGlobal_CMaoMinuto_2
# iteration 80
# link: https://www.cmjornal.pt/boa-vida/tendencias/detalhe/festival-gastronomia-de-bordo-chega-ao-mercado-de-peniche?ref=Futebol_CmaoMinuto
# iteration 81
# link: https://www.cmjornal.pt/boa-vida/tendencias/detalhe/festival-gastronomia-de-bordo-chega-ao-mercado-de-peniche?ref=HP_Africa_BlocoBoaVida
# iteration 82
# link: https://www.cmjornal.pt/boa-vida/tendencias/detalhe/festival-gastronomia-de-bordo-chega-ao-mercado-de-peniche?ref=HP_Africa_CMaoMinuto
# iteration 83
# link: https://www.cmjornal.pt/boa-vida/tendencias/detalhe/festival-gastronomia-de-bordo-chega-ao-mercado-de-peniche?ref=HP_BlocoBoaVida
# iteration 84
# link: https://www.cmjornal.pt/boa-vida/tendencias/detalhe/festival-gastronomia-de-bordo-chega-ao-mercado-de-peniche?ref=HP_CMaoMinuto
# iteration 85
# link: https://www.cmjornal.pt/boa-vida/tendencias/detalhe/festival-gastronomia-de-bordo-chega-ao-mercado-de-peniche?ref=Modalidades_CmaoMinuto
# iteration 86
# link: https://www.cmjornal.pt/boa-vida/tendencias/detalhe/festival-gastronomia-de-bordo-chega-ao-mercado-de-peniche?ref=Mundial2018_CmaoMinuto
# iteration 87
# link: https://www.cmjornal.pt/boa-vida/tendencias/detalhe/festival-gastronomia-de-bordo-chega-ao-mercado-de-peniche?ref=Opini%C3%A3o_CmaoMinuto
# iteration 88
# link: https://www.cmjornal.pt/boa-vida/tendencias/detalhe/festival-gastronomia-de-bordo-chega-ao-mercado-de-peniche?ref=Pol%C3%ADtica_CmaoMinuto
# iteration 89
# link: https://www.cmjornal.pt/boa-vida/tendencias/detalhe/festival-gastronomia-de-bordo-chega-ao-mercado-de-peniche?ref=Portugal_CmaoMinuto
# iteration 90
# link: https://www.cmjornal.pt/boa-vida/tendencias/detalhe/festival-gastronomia-de-bordo-chega-ao-mercado-de-peniche?ref=Programas_CMaoMinuto_2
# iteration 91
# link: https://www.cmjornal.pt/boa-vida/tendencias/detalhe/festival-gastronomia-de-bordo-chega-ao-mercado-de-peniche?ref=Sociedade_CmaoMinuto
# iteration 92
# link: https://www.cmjornal.pt/boa-vida/tendencias/detalhe/festival-gastronomia-de-bordo-chega-ao-mercado-de-peniche?ref=Ta%C3%A7adasConfedera%C3%A7%C3%B5es_CmaoMinuto
# iteration 93
# link: https://www.cmjornal.pt/boa-vida/tendencias/detalhe/festival-gastronomia-de-bordo-chega-ao-mercado-de-peniche?utm_medium=Social&utm_source=EnviarAmigo&utm_campaign=BotoesSite&utm_content=EnviarAmigo
# iteration 94
# link: https://www.cmjornal.pt/boa-vida/tendencias/detalhe/vienna-mozart-orchestra-chega-a-lisboa-para-um-concerto-de-natal
# iteration 95
# link: https://www.cmjornal.pt/boa-vida/tendencias/detalhe/vienna-mozart-orchestra-chega-a-lisboa-para-um-concerto-de-natal
# iteration 96
# link: https://www.cmjornal.pt/boa-vida/tendencias/detalhe/vienna-mozart-orchestra-chega-a-lisboa-para-um-concerto-de-natal?act=0&est=Aberto
# iteration 97
# link: https://www.cmjornal.pt/boa-vida/tendencias/detalhe/vienna-mozart-orchestra-chega-a-lisboa-para-um-concerto-de-natal?ref=CmaoMinuto_DestaquesPrincipais&act=0&est=Aberto
# iteration 98
# link: https://www.cmjornal.pt/boa-vida/tendencias/detalhe/vienna-mozart-orchestra-chega-a-lisboa-para-um-concerto-de-natal?ref=DET_CMaoMinuto_8&act=0&est=Aberto
# iteration 99
# link: https://www.cmjornal.pt/boa-vida/tendencias/detalhe/vienna-mozart-orchestra-chega-a-lisboa-para-um-concerto-de-natal?ref=Exclusivos_CmaoMinuto&act=0&est=Aberto
# iteration 100
# link: https://www.cmjornal.pt/boa-vida/tendencias/detalhe/vienna-mozart-orchestra-chega-a-lisboa-para-um-concerto-de-natal?ref=FalarGlobal_CMaoMinuto_8&act=0&est=Aberto
# iteration 101
# link: https://www.cmjornal.pt/boa-vida/tendencias/detalhe/vienna-mozart-orchestra-chega-a-lisboa-para-um-concerto-de-natal?ref=HP_Africa_BlocoBoaVida&act=0&est=Aberto
# iteration 102
# link: https://www.cmjornal.pt/boa-vida/tendencias/detalhe/vienna-mozart-orchestra-chega-a-lisboa-para-um-concerto-de-natal?ref=HP_Africa_BlocoBoaVida&act=0&est=Aberto
# iteration 103
# link: https://www.cmjornal.pt/boa-vida/tendencias/detalhe/vienna-mozart-orchestra-chega-a-lisboa-para-um-concerto-de-natal?ref=HP_BlocoBoaVida&act=0&est=Aberto
# iteration 104
# link: https://www.cmjornal.pt/boa-vida/tendencias/detalhe/vienna-mozart-orchestra-chega-a-lisboa-para-um-concerto-de-natal?ref=HP_BlocoBoaVida&act=0&est=Aberto
# iteration 105
# link: https://www.cmjornal.pt/boa-vida/tendencias/detalhe/vienna-mozart-orchestra-chega-a-lisboa-para-um-concerto-de-natal?ref=HP_CMaoMinuto_8&act=0&est=Aberto
# iteration 106
# link: https://www.cmjornal.pt/boa-vida/tendencias/detalhe/vienna-mozart-orchestra-chega-a-lisboa-para-um-concerto-de-natal?ref=HP_MaisComentadas&act=0&est=Aberto
# iteration 107
# link: https://www.cmjornal.pt/boa-vida/tendencias/detalhe/vienna-mozart-orchestra-chega-a-lisboa-para-um-concerto-de-natal?ref=Pesquisa_CmaoMinuto_8&act=0&est=Aberto
# iteration 108
# link: https://www.cmjornal.pt/boa-vida/tendencias/detalhe/vienna-mozart-orchestra-chega-a-lisboa-para-um-concerto-de-natal?ref=Programas_CMaoMinuto_8&act=0&est=Aberto
# iteration 109
# link: https://www.cmjornal.pt/boa-vida/tendencias/detalhe/vienna-mozart-orchestra-chega-a-lisboa-para-um-concerto-de-natal?ref=Cm%20ao%20Minuto_MaisComentadas
# iteration 110
# link: https://www.cmjornal.pt/boa-vida/tendencias/detalhe/vienna-mozart-orchestra-chega-a-lisboa-para-um-concerto-de-natal?ref=CmaoMinuto_DestaquesPrincipais
# iteration 111
# link: https://www.cmjornal.pt/boa-vida/tendencias/detalhe/vienna-mozart-orchestra-chega-a-lisboa-para-um-concerto-de-natal?ref=DET_CMaoMinuto_8
# iteration 112
# link: https://www.cmjornal.pt/boa-vida/tendencias/detalhe/vienna-mozart-orchestra-chega-a-lisboa-para-um-concerto-de-natal?ref=Exclusivos_CmaoMinuto
# iteration 113
# link: https://www.cmjornal.pt/boa-vida/tendencias/detalhe/vienna-mozart-orchestra-chega-a-lisboa-para-um-concerto-de-natal?ref=FalarGlobal_CMaoMinuto_8
# iteration 114
# link: https://www.cmjornal.pt/boa-vida/tendencias/detalhe/vienna-mozart-orchestra-chega-a-lisboa-para-um-concerto-de-natal?ref=HP_Africa_BlocoBoaVida
# iteration 115
# link: https://www.cmjornal.pt/boa-vida/tendencias/detalhe/vienna-mozart-orchestra-chega-a-lisboa-para-um-concerto-de-natal?ref=HP_Africa_BlocoBoaVida
# iteration 116
# link: https://www.cmjornal.pt/boa-vida/tendencias/detalhe/vienna-mozart-orchestra-chega-a-lisboa-para-um-concerto-de-natal?ref=HP_BlocoBoaVida
# iteration 117
# link: https://www.cmjornal.pt/boa-vida/tendencias/detalhe/vienna-mozart-orchestra-chega-a-lisboa-para-um-concerto-de-natal?ref=HP_BlocoBoaVida
# iteration 118
# link: https://www.cmjornal.pt/boa-vida/tendencias/detalhe/vienna-mozart-orchestra-chega-a-lisboa-para-um-concerto-de-natal?ref=HP_CMaoMinuto_8
# iteration 119
# link: https://www.cmjornal.pt/boa-vida/tendencias/detalhe/vienna-mozart-orchestra-chega-a-lisboa-para-um-concerto-de-natal?ref=HP_MaisComentadas
# iteration 120
# link: https://www.cmjornal.pt/boa-vida/tendencias/detalhe/vienna-mozart-orchestra-chega-a-lisboa-para-um-concerto-de-natal?ref=
# link: https://www.cmjornal.pt/cm-ao-minuto/detalhe/clima-mais-de-mil-alunos-em-coimbra-dizem-que-chega-de-bla-bla-bla-e-exigem-mudancas?ref=Sociedade_BlocoFimPagina&act=0&est=Aberto
# iteration 184
# link: https://www.cmjornal.pt/cm-ao-minuto/detalhe/clima-mais-de-mil-alunos-em-coimbra-dizem-que-chega-de-bla-bla-bla-e-exigem-mudancas?ref=sociedade_destaque&act=0&est=Aberto
# iteration 185
# link: https://www.cmjornal.pt/cm-ao-minuto/detalhe/clima-mais-de-mil-alunos-em-coimbra-dizem-que-chega-de-bla-bla-bla-e-exigem-mudancas?ref=sociedade_outras&act=0&est=Aberto
# iteration 186
# link: https://www.cmjornal.pt/cm-ao-minuto/detalhe/clima-mais-de-mil-alunos-em-coimbra-dizem-que-chega-de-bla-bla-bla-e-exigem-mudancas?ref=Boa%20Vida_BlocoTopoPagina
# iteration 187
# link: https://www.cmjornal.pt/cm-ao-minuto/detalhe/clima-mais-de-mil-alunos-em-coimbra-dizem-que-chega-de-bla-bla-bla-e-exigem-mudancas?ref=Cidades_BlocoFimPagina
# iteration 188
# link: https://www.cmjornal.pt/cm-ao-minuto/detalhe/clima-mais-de-mil-alunos-em-coimbra-dizem-que-chega-de-bla-bla-bla-e-exigem-mudancas?ref=Clima_BlocoFimPagina
# iteration 189
# link: https://www.cmjornal.pt/cm-ao-minuto/detalhe/clima-mais-de-mil-alunos-em-coimbra-dizem-que-chega-de-bla-bla-bla-e-exigem-mudancas?ref=clima_destaque
# iteration 190
# link: https://www.cmjornal.pt/cm-ao-minuto/detalhe/clima-mais-de-mil-alunos-em-coimbra-dizem-que-chega-de-bla-bla-bla-e-exigem-mudancas?ref=clima_outras
# iteration 191
# link: https://www.cmjornal.pt/cm-ao-minuto/detalhe/clima-mais-de-mil-alunos-em-coimbra-dizem-que-chega-de-bla-bla-bla-e-exigem-mudancas?ref=clima_outras
# iteration 192
# link: https://www.cmjornal.pt/cm-ao-minuto/detalhe/clima-mais-de-mil-alunos-em-coimbra-dizem-que-chega-de-bla-bla-bla-e-exigem-mudancas?ref=clima_outras
# iteration 193
# link: https://www.cmjornal.pt/cm-ao-minuto/detalhe/clima-mais-de-mil-alunos-em-coimbra-dizem-que-chega-de-bla-bla-bla-e-exigem-mudancas?ref=clima_outras
# iteration 194
# link: https://www.cmjornal.pt/cm-ao-minuto/detalhe/clima-mais-de-mil-alunos-em-coimbra-dizem-que-chega-de-bla-bla-bla-e-exigem-mudancas?ref=Cm%20ao%20Minuto_BlocoTopoPagina
# iteration 195
# link: https://www.cmjornal.pt/cm-ao-minuto/detalhe/clima-mais-de-mil-alunos-em-coimbra-dizem-que-chega-de-bla-bla-bla-e-exigem-mudancas?ref=Contacte-nos_BlocoTopoPagina
# iteration 196
# link: https://www.cmjornal.pt/cm-ao-minuto/detalhe/clima-mais-de-mil-alunos-em-coimbra-dizem-que-chega-de-bla-bla-bla-e-exigem-mudancas?ref=Desporto_BlocoFimPagina
# iteration 197
# link: https://www.cmjornal.pt/cm-ao-minuto/detalhe/clima-mais-de-mil-alunos-em-coimbra-dizem-que-chega-de-bla-bla-bla-e-exigem-mudancas?ref=DET_relacionadas
# iteration 198
# link: https://www.cmjornal.pt/cm-ao-minuto/detalhe/clima-mais-de-mil-alunos-em-coimbra-dizem-que-chega-de-bla-bla-bla-e-exigem-mudancas?ref=Exclusivos_BlocoFimPagina
# iteration 199
# link: https://www.cmjornal.pt/cm-ao-minuto/detalhe/clima-mais-de-mil-alunos-em-coimbra-dizem-que-chega-de-bla-bla-bla-e-exigem-mudancas?ref=Famosos_BlocoTopoPagina
# iteration 200
# link: https://www.cmjornal.pt/cm-ao-minuto/detalhe/clima-mais-de-mil-alunos-em-coimbra-dizem-que-chega-de-bla-bla-bla-e-exigem-mudancas?ref=Futebol_BlocoFimPagina
# iteration 201
# link: https://www.cmjornal.pt/cm-ao-minuto/detalhe/clima-mais-de-mil-alunos-em-coimbra-dizem-que-chega-de-bla-bla-bla-e-exigem-mudancas?ref=HP_Grupo1
# iteration 202
# link: https://www.cmjornal.pt/cm-ao-minuto/detalhe/clima-mais-de-mil-alunos-em-coimbra-dizem-que-chega-de-bla-bla-bla-e-exigem-mudancas?ref=Lei%20da%20Transpar%C3%AAncia_BlocoTopoPagina
# iteration 203
# link: https://www.cmjornal.pt/cm-ao-minuto/detalhe/clima-mais-de-mil-alunos-em-coimbra-dizem-que-chega-de-bla-bla-bla-e-exigem-mudancas?ref=Mundo_BlocoTopoPagina
# iteration 204
# link: https://www.cmjornal.pt/cm-ao-minuto/detalhe/clima-mais-de-mil-alunos-em-coimbra-dizem-que-chega-de-bla-bla-bla-e-exigem-mudancas?ref=Portugal_BlocoFimPagina
# iteration 205
# link: https://www.cmjornal.pt/cm-ao-minuto/detalhe/clima-mais-de-mil-alunos-em-coimbra-dizem-que-chega-de-bla-bla-bla-e-exigem-mudancas?ref=Portugal_BlocoTopoPagina
# iteration 206
# link: https://www.cmjornal.pt/cm-ao-minuto/detalhe/clima-mais-de-mil-alunos-em-coimbra-dizem-que-chega-de-bla-bla-bla-e-exigem-mudancas?ref=Sociedade_BlocoFimPagina
# iteration 207
# link: https://www.cmjornal.pt/cm-ao-minuto/detalhe/clima-mais-de-mil-alunos-em-coimbra-dizem-que-chega-de-bla-bla-bla-e-exigem-mudancas?ref=sociedade_destaque
# iteration 208
# link: https://www.cmjornal.pt/cm-ao-minuto/detalhe/clima-mais-de-mil-alunos-em-coimbra-dizem-que-chega-de-bla-bla-bla-e-exigem-mudancas?ref=sociedade_outras
# iteration 209
# link: https://www.cmjornal.pt/cm-ao-minuto/detalhe/clima-mais-de-mil-alunos-em-coimbra-dizem-que-chega-de-bla-bla-bla-e-exigem-mudancas?ref=Tv%20Media_BlocoTopoPagina
# iteration 210
# link: https://www.cmjornal.pt/cm-ao-minuto/detalhe/euro2020-cristiano-ronaldo-chega-aos-90-golos-por-portugal-na-lituania
# iteration 211
# link: https://www.cmjornal.pt/cm-ao-minuto/detalhe/euro2020-cristiano-ronaldo-chega-aos-90-golos-por-portugal-na-lituania?ref=DET_MaisVistasArea&act=0&est=Aberto
# iteration 212
# link: https://www.cmjornal.pt/cm-ao-minuto/detalhe/euro2020-cristiano-ronaldo-chega-aos-90-golos-por-portugal-na-lituania?ref=DET_MaisVistasArea
# iteration 213
# link: https://www.cmjornal.pt/cm-ao-minuto/detalhe/fc-porto-chega-a-final-da-youth-league-ao-vencer-hoffenheim?ref=Cidades_BlocoFimPagina&act=0&est=Aberto
# iteration 214
# link: https://www.cmjornal.pt/cm-ao-minuto/detalhe/fc-porto-chega-a-final-da-youth-league-ao-vencer-hoffenheim?ref=Clima_BlocoFimPagina&act=0&est=Aberto
# iteration 215
# link: https://www.cmjornal.pt/cm-ao-minuto/detalhe/fc-porto-chega-a-final-da-youth-league-ao-vencer-hoffenheim?ref=Contacte-nos_BlocoTopoPagina&act=0&est=Aberto
# iteration 216
# link: https://www.cmjornal.pt/cm-ao-minuto/detalhe/fc-porto-chega-a-final-da-youth-league-ao-vencer-hoffenheim?ref=Desporto_BlocoFimPagina&act=0&est=Aberto
# iteration 217
# link: https://www.cmjornal.pt/cm-ao-minuto/detalhe/fc-porto-chega-a-final-da-youth-league-ao-vencer-hoffenheim?ref=Desporto_BlocoTopoPagina&act=0&est=Aberto
# iteration 218
# link: https://www.cmjornal.pt/cm-ao-minuto/detalhe/fc-porto-chega-a-final-da-youth-league-ao-vencer-hoffenheim?ref=Exclusivos_BlocoFimPagina&act=0&est=Aberto
# iteration 219
# link: https://www.cmjornal.pt/cm-ao-minuto/detalhe/fc-porto-chega-a-final-da-youth-league-ao-vencer-hoffenheim?ref=Futebol_BlocoFimPagina&act=0&est=Aberto
# iteration 220
# link: https://www.cmjornal.pt/cm-ao-minuto/detalhe/fc-porto-chega-a-final-da-youth-league-ao-vencer-hoffenheim?ref=HP_Grupo1&act=0&est=Aberto
# iteration 221
# link: https://www.cmjornal.pt/cm-ao-minuto/detalhe/fc-porto-chega-a-final-da-youth-league-ao-vencer-hoffenheim?ref=Modalidades_BlocoFimPagina&act=0&est=Aberto
# iteration 222
# link: https://www.cmjornal.pt/cm-ao-minuto/detalhe/fc-porto-chega-a-final-da-youth-league-ao-vencer-hoffenheim?ref=Mundo_BlocoTopoPagina&act=0&est=Aberto
# iteration 223
# link: https://www.cmjornal.pt/cm-ao-minuto/detalhe/fc-porto-chega-a-final-da-youth-league-ao-vencer-hoffenheim?ref=Portugal_BlocoFimPagina&act=0&est=Aberto
# iteration 224
# link: https://www.cmjornal.pt/cm-ao-minuto/detalhe/fc-porto-chega-a-final-da-youth-league-ao-vencer-hoffenheim?ref=Portugal_BlocoTopoPagina&act=0&est=Aberto
# iteration 225
# link: https://www.cmjornal.pt/cm-ao-minuto/detalhe/fc-porto-chega-a-final-da-youth-league-ao-vencer-hoffenheim?ref=Sociedade_BlocoFimPagina&act=0&est=Aberto
# iteration 226
# link: https://www.cmjornal.pt/cm-ao-minuto/detalhe/fc-porto-chega-a-final-da-youth-league-ao-vencer-hoffenheim?ref=Cidades_BlocoFimPagina
# iteration 227
# link: https://www.cmjornal.pt/cm-ao-minuto/detalhe/fc-porto-chega-a-final-da-youth-league-ao-vencer-hoffenheim?ref=Clima_BlocoFimPagina
# iteration 228
# link: https://www.cmjornal.pt/cm-ao-minuto/detalhe/fc-porto-chega-a-final-da-youth-league-ao-vencer-hoffenheim?ref=Cm%20ao%20Minuto_BlocoTopoPagina
# iteration 229
# link: https://www.cmjornal.pt/cm-ao-minuto/detalhe/fc-porto-chega-a-final-da-youth-league-ao-vencer-hoffenheim?ref=Contacte-nos_BlocoTopoPagina
# iteration 230
# link: https://www.cmjornal.pt/cm-ao-minuto/detalhe/fc-porto-chega-a-final-da-youth-league-ao-vencer-hoffenheim?ref=Desporto_BlocoFimPagina
# iteration 231
# link: https://www.cmjornal.pt/cm-ao-minuto/detalhe/fc-porto-chega-a-final-da-youth-league-ao-vencer-hoffenheim?ref=Desporto_BlocoTopoPagina
# iteration 232
# link: https://www.cmjornal.pt/cm-ao-minuto/detalhe/fc-porto-chega-a-final-da-youth-league-ao-vencer-hoffenheim?ref=Exclusivos_BlocoFimPagina
# iteration 233
# link: https://www.cmjornal.pt/cm-ao-minuto/detalhe/fc-porto-chega-a-final-da-youth-league-ao-vencer-hoffenheim?ref=Futebol_BlocoFimPagina
# iteration 234
# link: https://www.cmjornal.pt/cm-ao-minuto/detalhe/fc-porto-chega-a-final-da-youth-league-ao-vencer-hoffenheim?ref=HP_Grupo1
# iteration 235
# link: https://www.cmjornal.pt/cm-ao-minuto/detalhe/fc-porto-chega-a-final-da-youth-league-ao-vencer-hoffenheim?ref=Lei%20da%20Transpar%C3%AAncia_BlocoTopoPagina
# iteration 236
# link: https://www.cmjornal.pt/cm-ao-minuto/detalhe/fc-porto-chega-a-final-da-youth-league-ao-vencer-hoffenheim?ref=Modalidades_BlocoFimPagina
# iteration 237
# link: https://www.cmjornal.pt/cm-ao-minuto/detalhe/fc-porto-chega-a-final-da-youth-league-ao-vencer-hoffenheim?ref=Mundo_BlocoTopoPagina
# iteration 238
# link: https://www.cmjornal.pt/cm-ao-minuto/detalhe/fc-porto-chega-a-final-da-youth-league-ao-vencer-hoffenheim?ref=Portugal_BlocoFimPagina
# iteration 239
# link: https://www.cmjornal.pt/cm-ao-minuto/detalhe/fc-porto-chega-a-final-da-youth-league-ao-vencer-hoffenheim?ref=